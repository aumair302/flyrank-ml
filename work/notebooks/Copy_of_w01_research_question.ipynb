# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## My Lane (or Freestyle) and Why

**Lane:** Lane 2 - Refresh / Content Opportunity Scoring

I selected Lane 2 because it helps identify which webpages should be reviewed first for improvement. This can help improve website performance by focusing on pages that may need updating, refreshing, or monitoring.
"""))
# Out:
# ## My Lane (or Freestyle) and Why
#
# **Lane:** Lane 2 - Refresh / Content Opportunity Scoring
#
# I selected Lane 2 because it helps identify which webpages should be reviewed first for improvement. This can help improve website performance by focusing on pages that may need updating, refreshing, or monitoring.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# !pwd
# Out:
# /content

# %%
# !git clone https://github.com/aumair302/flyrank-ml.git
# Out:
# Cloning into 'flyrank-ml'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 98 (delta 20), reused 80 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 1.83 MiB | 14.79 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# !find /content/flyrank-ml -name "*.csv"
# Out:
# /content/flyrank-ml/outputs/refresh_queue_sample.csv
# /content/flyrank-ml/data/raw/content_refresh_anonymized.csv

# %%
from IPython.display import Markdown, display

display(Markdown("""
## 2. The Question: Decision, Action, Cost of a Wrong Call

**Research Question:**
Which webpages should be reviewed first for refresh or improvement?

**Decision:**
The SEO team decides which webpages should be refreshed first.

**Action:**
Review and update the selected webpages by improving their content, titles, or information.

**Cost of a Wrong Call:**
If a page is incorrectly selected, time and effort may be wasted. If an important page is missed, the website may lose traffic and engagement.

**Unit of Analysis:**
One webpage.

**Output:**
A ranked list of webpages that should be reviewed for refresh.
"""))
# Out:
# ## 2. The Question: Decision, Action, Cost of a Wrong Call
#
# **Research Question:**
# Which webpages should be reviewed first for refresh or improvement?
#
# **Decision:**
# The SEO team decides which webpages should be refreshed first.
#
# **Action:**
# Review and update the selected webpages by improving their content, titles, or information.
#
# **Cost of a Wrong Call:**
# If a page is incorrectly selected, time and effort may be wasted. If an important page is missed, the website may lose traffic and engagement.
#
# **Unit of Analysis:**
# One webpage.
#
# **Output:**
# A ranked list of webpages that should be reviewed for refresh.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
from IPython.display import Markdown, display

# Load the starter dataset
df = pd.read_csv("/content/flyrank-ml/data/raw/content_refresh_anonymized.csv")

# Get 3 real numbers
rows = df.shape[0]
columns = df.shape[1]
missing = df.isnull().sum().sum()

# Print the numbers
print("Rows:", rows)
print("Columns:", columns)
print("Missing values:", missing)

# Display the explanation
display(Markdown(f"""
## 3. Quick Look at the Data

The starter dataset contains **{rows}** rows and **{columns}** columns.

The dataset has **{missing}** missing values.

These numbers show that the dataset contains enough information to analyze webpage performance and identify pages that may need refreshing. This supports my choice of **Lane 2: Refresh / Content Opportunity Scoring**.
"""))
# Out:
# Rows: 30000
# Columns: 44
# Missing values: 73868
# ## 3. Quick Look at the Data
#
# The starter dataset contains **30000** rows and **44** columns.
#
# The dataset has **73868** missing values.
#
# These numbers show that the dataset contains enough information to analyze webpage performance and identify pages that may need refreshing. This supports my choice of **Lane 2: Refresh / Content Opportunity Scoring**.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## 4. Careful Words: What I Can and Can't Claim

This project is only a starting point for analysis. The results will show patterns in the data, but they do not prove that one factor causes another.

The recommendations should be used as guidance for review, not as guaranteed actions. Any important decision should be checked by a human before making changes.

The machine learning model may make mistakes, so its predictions should be validated before they are used.
"""))
# Out:
# ## 4. Careful Words: What I Can and Can't Claim
#
# This project is only a starting point for analysis. The results will show patterns in the data, but they do not prove that one factor causes another.
#
# The recommendations should be used as guidance for review, not as guaranteed actions. Any important decision should be checked by a human before making changes.
#
# The machine learning model may make mistakes, so its predictions should be validated before they are used.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
