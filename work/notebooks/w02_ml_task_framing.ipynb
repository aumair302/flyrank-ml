# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
print("My Lane as an ML Task")
print("Task Type: Scoring")
print("My lane is Content Opportunity Scoring.")
print("The model gives each content page a score.")
print("Higher score = refresh first.")
# Out:
# My Lane as an ML Task
# Task Type: Scoring
# My lane is Content Opportunity Scoring.
# The model gives each content page a score.
# Higher score = refresh first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
print("Target or Proxy")
print("Target: Content Opportunity Score")
print("Higher score means the page should be refreshed first.")
# Out:
# Target or Proxy
# Target: Content Opportunity Score
# Higher score means the page should be refreshed first.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
print("Success Metric")
print("Mean Absolute Error (MAE)")
print("Lower MAE means better predictions.")
# Out:
# Success Metric
# Mean Absolute Error (MAE)
# Lower MAE means better predictions.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.DataFrame({
    "page_id": [1, 2, 3],
    "clicks": [120, 85, 200],
    "impressions": [1000, 700, 1800],
    "opportunity_score": [0.80, 0.45, 0.92]
})

print("Unit of Analysis")
print("One row represents one content page.")

df.head()
# Out:
# Unit of Analysis
# One row represents one content page.
#    page_id  clicks  impressions  opportunity_score
# 0        1     120         1000               0.80
# 1        2      85          700               0.45
# 2        3     200         1800               0.92

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
print("Why ML beats a fixed rule")
print("Machine Learning looks at many features together.")
print("It predicts better than a simple fixed rule.")
print("This helps decide which content should be refreshed first.")
# Out:
# Why ML beats a fixed rule
# Machine Learning looks at many features together.
# It predicts better than a simple fixed rule.
# This helps decide which content should be refreshed first.

# %% [markdown]
# [link text](https://)

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
