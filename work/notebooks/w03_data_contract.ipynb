# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/NiwateNandini/ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
print("Unit of Analysis + Time Window")
print("One row represents one content page for one month.")
print("Time Window: March 2026")
# Out:
# Unit of Analysis + Time Window
# One row represents one content page for one month.
# Time Window: March 2026

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
print("Fields")

print("\nFeatures:")
print("- Clicks")
print("- Impressions")
print("- Position")
print("- CTR")
print("- Device")

print("\nLabel:")
print("- Content Opportunity Score")

print("\nContext:")
print("- Page ID")
print("- Month")
print("- Date")

print("\nExcluded:")
print("- Client names")
print("- URLs")
print("- Private search queries")
print("Reason: These fields are excluded because they are not required for prediction and help protect privacy.")
# Out:
# Fields
#
# Features:
# - Clicks
# - Impressions
# - Position
# - CTR
# - Device
#
# Label:
# - Content Opportunity Score
#
# Context:
# - Page ID
# - Month
# - Date
#
# Excluded:
# - Client names
# - URLs
# - Private search queries
# Reason: These fields are excluded because they are not required for prediction and help protect privacy.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
import pandas as pd

# Sample data for verification
df = pd.DataFrame({
    "page_id": [1, 2, 3],
    "month": ["2026-03", "2026-03", "2026-03"],
    "clicks": [120, 85, 200],
    "impressions": [1000, 700, 1800],
    "available": [True, True, True]
})

# Query 1: Verify Grain
print("Query 1: Verify Grain")
print("One row = One content page for one month")
print(df[["page_id", "month"]])

# Query 2: Row Count and Time Window
print("\nQuery 2: Row Count and Time Window")
print("Total Rows:", len(df))
print("Start Month:", df["month"].min())
print("End Month:", df["month"].max())

# Query 3: Availability Check
print("\nQuery 3: Availability Check")
available_rows = df[df["available"] == True]
print("Rows Available:", len(available_rows))
print(available_rows)
# Out:
# Query 1: Verify Grain
# One row = One content page for one month
#    page_id    month
# 0        1  2026-03
# 1        2  2026-03
# 2        3  2026-03
#
# Query 2: Row Count and Time Window
# Total Rows: 3
# Start Month: 2026-03
# End Month: 2026-03
#
# Query 3: Availability Check
# Rows Available: 3
#    page_id    month  clicks  impressions  available
# 0        1  2026-03     120         1000       True
# 1        2  2026-03      85          700       True
# 2        3  2026-03     200         1800       True

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
print("Data Limits")
print("The dataset only contains available search data.")
print("It cannot explain every reason why content performs well or poorly.")
print("The analysis is limited to the selected month and available warehouse data.")
# Out:
# Data Limits
# The dataset only contains available search data.
# It cannot explain every reason why content performs well or poorly.
# The analysis is limited to the selected month and available warehouse data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
